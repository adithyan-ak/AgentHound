# %% [markdown]
# # AgentHound offline QA fixture
#
# All credentials in this notebook are obvious non-production placeholders.

# %%
OPENAI_API_KEY = "sk-placeholder-jupyter-openai-key-not-real"
ANTHROPIC_API_KEY = "sk-ant-placeholder-jupyter-key-not-real"
LITELLM_MASTER_KEY = "sk-local-agenthound-master-key-not-production"

fixture = {
    "purpose": "deterministic local collector QA",
    "production": False,
}
fixture
